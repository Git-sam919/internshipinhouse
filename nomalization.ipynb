# %%
import pandas as pd
from sklearn.preprocessing import MinMaxScaler, StandardScaler

# Sample DataFrame (replace with your own df)
df = pd.DataFrame({
    "A": [10, 20, 30, 40],
    "B": [5, 15, 25, 35]
})

# Min–Max Normalization (0–1)
minmax_scaler = MinMaxScaler()
df_minmax = pd.DataFrame(minmax_scaler.fit_transform(df), columns=df.columns)

# Z-Score Normalization (Standardization)
std_scaler = StandardScaler()
df_zscore = pd.DataFrame(std_scaler.fit_transform(df), columns=df.columns)

print("Min–Max Normalized Data:")
print(df_minmax, "\n")

print("Z-Score Normalized Data:")
print(df_zscore)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 2
#       1 import pandas as pd
# ----> 2 from sklearn.preprocessing import MinMaxScaler, StandardScaler
#       4 # Sample DataFrame (replace with your own df)
#       5 df = pd.DataFrame({
#       6     "A": [10, 20, 30, 40],
#       7     "B": [5, 15, 25, 35]
#       8 })
#
# ModuleNotFoundError: No module named 'sklearn'
